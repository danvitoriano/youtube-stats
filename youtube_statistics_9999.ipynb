# %% [markdown]
# <a href="https://colab.research.google.com/github/danvitoriano/youtube-stats/blob/main/youtube_statistics_9999.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import string
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('rslp')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package rslp to /root/nltk_data...
# [nltk_data]   Unzipping stemmers/rslp.zip.

# %%
pd.set_option('max_rows', 9999)
dataset = pd.read_csv('/content/drive/My Drive/USvideos - USvideos.csv')
dataset
# Out:
#          video_id  ...                                        description
# 0     2kyS6SvSYSE  ...  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1     1ZAPwfrtAFY  ...  One year after the presidential election, John...
# 2     5qpjK5DgCt4  ...  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3     puqaWrEC7tY  ...  Today we find out if Link is a Nickelback amat...
# 4     d380meD0W0M  ...  I know it's been a while since we did this sho...
# 5     gHZ1Qz0KiKM  ...  Using the iPhone for the past two weeks -- her...
# 6     39idVpFF7NQ  ...  Embattled Alabama Senate candidate Roy Moore (...
# 7     nc99ccSXST0  ...  Ice Cream Pint Combination Lock - http://amzn....
# 8     jr9QtXwC9vc  ...  Inspired by the imagination of P.T. Barnum, Th...
# 9     TUmyygCMMGA  ...  For now, at least, we have better things to wo...
# 10    9wRQljFNDW8  ...  New England Patriots returner Dion Lewis blast...
# 11    VifQlJit6A0  ...  Shiva arrives just in time as King Ezekiel att...
# ...

# %%
# filtering channel title
dataset = dataset[['title']]
dataset
# Out:
#                                                   title
# 0                    WE WANT TO TALK ABOUT OUR MARRIAGE
# 1     The Trump Presidency: Last Week Tonight with J...
# 2     Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                      Nickelback Lyrics: Real or Fake?
# 4                              I Dare You: GOING BALD!?
# 5                                 2 Weeks with iPhone X
# 6             Roy Moore & Jeff Sessions Cold Open - SNL
# 7                   5 Ice Cream Gadgets put to the Test
# 8     The Greatest Showman | Official Trailer 2 [HD]...
# 9     Why the rise of the robots won’t mean the end ...
# 10    Dion Lewis' 103-Yd Kick Return TD vs. Denver! ...
# 11    (SPOILERS) 'Shiva Saves the Day' Talked About ...
# 12           Marshmello - Blocks (Official Music Video)
# 13               Which Countries Are About To Collapse?
# 14                             SHOPPING FOR NEW FISH!!!
# 15                                     The New SpotMini
# ...

# %%
# remoção de pontuacao e stopwords

def remove_stopwords(text,lang,domain_stopwords=[]):
  
  stop_words = nltk.corpus.stopwords.words(lang) # lang='portuguese' or lang='english'
  
  s = str(text).lower() # tudo para caixa baixa
  table = str.maketrans({key: None for key in string.punctuation})
  s = s.translate(table) # remove pontuacao
  tokens = word_tokenize(s) #obtem tokens
  v = [i for i in tokens if not i in stop_words and not i in domain_stopwords and not i.isdigit() and len(i) > 2] # remove stopwords
  s = ""
  for token in v:
    s += token+" "
  return s.strip()


# exemplos de uso
dataset2 = remove_stopwords(dataset, 'english')
print(dataset2)
# Out:
# title want talk marriage trump presidency last week tonight racist superman rudy mancuso king bach nickelback lyrics real fake dare going bald weeks iphone roy moore jeff sessions cold open snl ice cream gadgets put test greatest showman official trailer rise robots mean end dion lewis 103yd kick return denver spoilers shiva saves day talked marshmello blocks official music video countries collapse shopping new fish new spotmini one change would make pacific rim classic body know youre full hilary homemade electric airplane founding inbreedingfree space colony control dreams making helas headdress thor ragn dangerous talk camera driv get nyc sweet digs using peoples showers spaghetti burrito spaghetti burrito proth primes numberphile smart mug take apart heated thermos lebron james admits ripping phil jackso nick andopolis drummer took lambo carmax amazon christmas advert toys games eminem walk water audio beyoncé whats inside detectives car new emirates first class suite boeing meo 
# ...

# %%
wordlist = dataset2.split()

wordfreq = []
for w in wordlist:
    wordfreq.append(wordlist.count(w))

print("List\n" + str(wordlist) + "\n")
print("Frequencies\n" + str(wordfreq) + "\n")

listFinal = str(sorted(list(set(zip(wordlist, wordfreq))), key=lambda tup: tup[1], reverse=True))

print("Pairs\n" + listFinal)
# Out:
# List
# ...
